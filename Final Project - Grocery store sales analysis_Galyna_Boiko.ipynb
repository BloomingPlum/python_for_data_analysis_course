# %% [markdown]
# # Вітаю на фінальному проєкті!
# Протягом курсу ми навчились завантажувати дані в Python, трансформувати їх, чистити, агрегувати, знаходити з допомогою даних відповіді на наші питання.
# Задача фінального проєкту - продемонструвати той рівень роботи з даними, на якому ви є зараз.
#
# Цей ноутбук буде присвячений аналізу даних з файла `Grocery DataBase.xlsx`, який є в папці `Дані` на Диску. Так, це Excel файл, але ми можемо дуже просто завантажувати дані з нього у Python. Покажу пару команд для роботи з Excel файлом.

# %% [markdown]
# Для початку встановимо бібліотеку, яка потрібна для роботи з Excel файлами з pandas. Можна встановити тут, або в терміналі, але якщо Ви встановлюєте в терміналі, то після того треба перезапустити ядро (Kernel) ноутбуку, аби бібліотека точно підтягнулась. Іноді підтягується і без того, але це на випадок, що робити, якщо компілятор каже, що її не бачить.

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\galyna\anaconda3\envs\venv1\lib\site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in c:\users\galyna\anaconda3\envs\venv1\lib\site-packages (from openpyxl) (1.1.0)

# %%
! pip install xlrd
# Out:
# Requirement already satisfied: xlrd in c:\users\galyna\anaconda3\envs\venv1\lib\site-packages (2.0.1)

# %%
import pandas as pd

# %% [markdown]
# Ось так можемо переглянути, які є листки в Excel файлі:

# %%
# замініть на шлях до файлу на своєму комп`ютері

path_to_file = 'data/FP/GroceryDatabase.xlsx'

# %%
xl = pd.ExcelFile(path_to_file, engine='openpyxl')
xl.sheet_names
# Out:
# ['Grosto DB', 'Sheet2', 'Fact Summary']

# %% [markdown]
# А так можемо зчитати конкретний листок:

# %%
xl.parse('Fact Summary')
# Out:
#     S.No.          Column Name  \
# 0       1       Receipt Number
# 1       2                 Date
# 2       3                 Year
# 3       4                Month
# 4       5                 Time
# 5       6        Mobile Number
# 6       7        Membership ID
# 7       8  Loyalty Card Points
# 8       9                  Age
# 9      10               Gender
# 10     11                 City
# 11     12              Country
# 12     13             Category
# 13     14         Sub_Category
# 14     15                Items
# 15     16               Brand
# 16     17         Description
# 17     18                Price
# 18     19                  QTY
# 19     20                 DISC
# 20     21      Net Bill Amount
# 21     22                  GST
# 22     23    Gross Bill Amount
# 23     24         Payment Mode
# 24     25            Bank Name
# 25     26      % Profit Margin
# 26     27     % Operating Cost
# 27     28       % Product Cost
# 28     29        Profit Margin
# 29     30       Operating Cost
# 30     31         Product Cost
#
#                       Description of the Column names
# 0                                  Transaction Number
# 1                                 Date of Transaction
# 2                                 Year of Transaction
# 3                                Month of Transaction
# 4                             Time of the transaction
# 5                      Monbile number of the customer
# 6                Unique Membership ID of the Customer
# 7   Loyalty Points earned by customer (10 Points/1...
# 8         Age of the Customer in the Company Database
# 9                              Gender of the customer
# 10                                 City Name of store
# 11                              Country Name of store
# 12                Category of Item bought by customer
# 13            Sub-Category of Item bought by customer
# 14               Name if the item  bought by customer
# 15                           Brand of the Item bought
# 16  Description of the Item (weight/volume/pack si...
# 17                         Price per unit of the Item
# 18                    Quantity bought by the cistomer
# 19                          Discount offered by store
# 20        Amount exclusive of tax payable to customer
# 21                                        Tax Payable
# 22  Gross Bill to be paid by customer inclusive of...
# 23                  Mode of payment opted by customer
# 24                                   Name of the Bank
# 25                  Percentage profit margin of store
# 26                 Percentage operating cost of store
# 27                   Percentage product cost to store
# 28                      Profit Margin earned by store
# 29                 Operating cost beared by the store
# 30                         Product Cost for the store

# %% [markdown]
# Читати дані можна і з Pandas, але тут немає можливості переглянути наявні листки, а також довше відбувається читання даних.

# %%
df = pd.read_excel(path_to_file, engine='openpyxl')

# %% [markdown]
# В файлі ви знайдете самі дані та опис колонок.
#
# **Задача**: Уявіть, що Вам дали цей набір даних з питанням "Що корисного ми можемо з них взяти для розвитку нашого бізнесу?". То Вам необхідно розказати бізнесу історію про ці дані у форматі
# 1. питання, яке Вас як робітника цього бізнесу, який дуже вболіває за його успіх, цікавить щодо цих даних
# 2. код для відповіді на це питання
# 3. висновки, які я можу зробити з огляду на результат виконання коду: які рішення ми можемо прийняти щодо подальших кроків в аналізі або які рекомендації Ви б дали бізнесу виходячи з результатів.
#
# **Необхідно** поставити до даних _мінімум_ 10 бізнес-питань, при цьому зробивши
# - початковий аналіз даних: їх розмір, структура, наявність пропущених значень та що з ними зробити, зміна типів даних там, де це доречно зробити (наприклад, якщо колонка завантажилась як тип string, а з опису видно, що там має бути float) - ця частина не входить у бізнес-питання, але є необхідною при аналізі даних.
# - _мінімум_ 1 зведену таблицю або її аналог
# - _мінімум_ 5 візуалізацій, 3 з яких мають різний тип (наприклад, scatter plot, line plot, pair plot)
#
# В даному мінімум-наборі немає вимоги на використання SQL та тестування статистичних гіпотез. Але якщо Вам хочеться потренуватись, то Ви можете це зробити скориставшись pandasql, а також перевірити, чи є відмінність між двома групами у якомусь показнику з допомогою тестування статистичних гіпотез. Останнє найбільш доречно, якщо, наприклад, ми беремо чоловіків і жінок, бачимо що у них доволі схожі середні чеки, але наче відрізняються. Аби зрозуміти, чи різниця статистично значущою, можна це перевірити з допомогою тестування стат. гіпотез.
#
# Питанням може бути як "Яка є кількість унікальних чеків в цьому наборі даних?" так і щось значно складніше. Якщо у Вас складне питання, і аби відповісти на нього Ви мали відповісти на 3 менших питання (зробити якісь трансформації над даними, подивитись щось), то це рахується як 3 питання з 10 необхідних у завданні. Звісно ж Ви можете зробити більше за встановлений мінімум - все буде перевірено :)
#
# Тут є великий простір для Вашої фантазії. **Тому рекомендація:** виділіть на це завданні певну кількість годин (наприклад, середнє значення по тому, скільки у Вас займало виконання домашніх завдань в курсі, але я рекомендую не менше 2х годин роботи)
# і поставте собі за ціль всю роботу вмістити в цю кількість годин.
# Це дозволить Вам управляти своїм часом, пріоритизувати питання, які ставите до даних. І так часто є в роботі: коли ми не знаємо, що ми шукаємо, ми ставимо обмеження по часу (задача типу spike) і робимо все, що встигнемо, за цей час.
#
# По закінченню - завантажуємо ноутбук на git і додаємо посилання в здачу роботи в Eduflow.
# До речі, з часом, вам може захотітись доповнити цей ноутбук, коли арсенал ваших навичок по роботі з даними розшириться. І це буде чудова ідея!
#
# **Успіхів!**

# %% [markdown]
# Спочатку подивимось на розмір даних та проаналізуємо їх типи:

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df_shape = df.shape
df_shape
# Out:
# (50447, 33)

# %%
df.head()
# Out:
#   Receipt Number       Date  Year  Month             Time  Mobile Number  \
# 0       GIJ00001 2016-01-02  2016      1  10:08:03.260000     9793548581
# 1       GIJ00002 2016-01-02  2016      1  15:46:50.832000     9938441276
# 2       GIJ00003 2016-01-02  2016      1  11:28:52.166000     9976742552
# 3       GIJ00003 2016-01-02  2016      1  11:28:52.166000     9976742552
# 4       GIJ00003 2016-01-02  2016      1  11:28:52.166000     9976742552
#
#   Membership ID  Loyalty Card Points  Age  Gender  ...  GST Gross Bill Amount  \
# 0     MIDID0001                    1   36    Male  ...  0.1          13.32408
# 1     MIDID0002                    2   54    Male  ...  0.1          25.26480
# 2     MIDID0003                    1   16  Female  ...  0.1          42.18786
# 3     MIDID0003                    1   16  Female  ...  0.1          42.18786
# 4     MIDID0003                    2   16  Female  ...  0.1          42.18786
#
#   Payment Mode                 Bank Name % Profit Margin % Operating Cost  \
# 0         Card           Enterprise Bank           0.150             0.15
# 1         Card  Philippine Veterans Bank           0.118             0.15
# 2         Cash               BDO Unibank           0.147             0.15
# 3         Cash               BDO Unibank           0.095             0.15
# 4         Cash               BDO Unibank           0.120             0.15
#
#   % Product Cost  Profit Margin  Operating Cost  Product Cost
# 0          0.700        1.85400          1.8540       8.65200
# 1          0.732        2.73760          3.4800      16.98240
# 2          0.703        1.95657          1.9965       9.35693
# 3          0.755        0.33440          0.5280       2.65760
# 4          0.730        0.52920          0.6615       3.21930
#
# [5 rows x 32 columns]

# %%
df.dtypes
# Out:
# Receipt Number                 object
# Date                   datetime64[ns]
# Year                            int64
# Month                           int64
# Time                           object
# Mobile Number                   int64
# Membership ID                  object
# Loyalty Card Points             int64
# Age                             int64
# Gender                         object
# City                           object
# Country                        object
# Category                       object
# Sub_Category                   object
# Items                          object
# Brand                          object
# Description                    object
# Price                         float64
# QTY                             int64
# DISC                          float64
# Amount                        float64
# Net Bill Amount               float64
# GST                           float64
# Gross Bill Amount             float64
# Payment Mode                   object
# Bank Name                      object
# % Profit Margin               float64
# % Operating Cost              float64
# % Product Cost                float64
# Profit Margin                 float64
# Operating Cost                float64
# Product Cost                  float64
# dtype: object

# %% [markdown]
# В принципі, практично нічого в типах даних змінювати не потрібно.

# %%
df.head(50)
# Out:
#    Receipt Number       Date  Year  Month      Time  Mobile Number  \
# 0        GIJ00001 2016-01-02  2016      1  10:08:03     9793548581
# 1        GIJ00002 2016-01-02  2016      1  15:46:50     9938441276
# 2        GIJ00003 2016-01-02  2016      1  11:28:52     9976742552
# 3        GIJ00003 2016-01-02  2016      1  11:28:52     9976742552
# 4        GIJ00003 2016-01-02  2016      1  11:28:52     9976742552
# 5        GIJ00003 2016-01-02  2016      1  11:28:52     9976742552
# 6        GIJ00003 2016-01-02  2016      1  11:28:52     9976742552
# 7        GIJ00003 2016-01-02  2016      1  11:28:52     9976742552
# 8        GIJ00004 2016-01-03  2016      1  20:52:55     9800896004
# 9        GIJ00004 2016-01-03  2016      1  20:52:55     9800896004
# 10       GIJ00004 2016-01-03  2016      1  20:52:55     9800896004
# 11       GIJ00004 2016-01-03  2016      1  20:52:55     9800896004
# 12       GIJ00005 2016-01-03  2016      1  15:47:23     9873085193
# 13       GIJ00006 2016-01-04  2016      1  17:40:37     9825440742
# 14       GIJ00007 2016-01-04  2016      1  19:08:20     9855991817
# 15       GIJ00008 2016-01-04  2016      1  13:09:09     9871678863
# 24          11.62656         Cash               BDO Unibank           0.093
# 25          11.62656         Cash               BDO Unibank           0.094
# 26          21.70278         Cash               BDO Unibank           0.128
# 27          21.70278         Cash               BDO Unibank           0.073
# 28         102.03380         Card               BDO Unibank           0.120
# 29         102.03380         Card               BDO Unibank           0.051
# 30         102.03380         Card               BDO Unibank           0.136
# 31         102.03380         Card               BDO Unibank           0.109
# 32         102.03380         Card               BDO Unibank           0.128
# 33         102.03380         Card               BDO Unibank           0.051
# 34          40.01536         Cash           Enterprise Bank           0.084
# 35          40.01536         Cash           Enterprise Bank           0.138
# 36          40.01536         Cash           Enterprise Bank           0.148
# 37          21.77780         Cash                  ING Bank           0.073
# 38          21.77780         Cash                  ING Bank           0.075
# 39          21.77780         Cash                  ING Bank           0.053
# 40          24.49832         Cash               BDO Unibank           0.107
# 41          39.39364         Card               BDO Unibank           0.144
# 42          39.39364         Card               BDO Unibank           0.126
# 43          39.39364         Card               BDO Unibank           0.133
# 44          97.26860       Wallet               BDO Unibank           0.075
# 45          97.26860       Wallet               BDO Unibank           0.133
# 46          97.26860       Wallet               BDO Unibank           0.148
# 47          97.26860       Wallet               BDO Unibank           0.076
# 48          97.26860       Wallet               BDO Unibank           0.107
# 49          97.26860       Wallet               BDO Unibank           0.068
#
#    % Operating Cost % Product Cost  Profit Margin  Operating Cost  \
# 0              0.15          0.700        1.85400          1.8540
# 1              0.15          0.732        2.73760          3.4800
# 2              0.15          0.703        1.95657          1.9965
# 3              0.15          0.755        0.33440          0.5280
# 4              0.15          0.730        0.52920          0.6615
# 5              0.15          0.730        0.33720          0.4215
# 6              0.15          0.755        0.31160          0.4920
# 7              0.15          0.755        0.35625          0.5625
# 8              0.15          0.702        0.86432          0.8760
# 9              0.15          0.774        0.55480          1.0950
# 10             0.15          0.702        0.96200          0.9750
# 11             0.15          0.702        0.75480          0.7650
# 12             0.15          0.762        0.56760          0.9675
# 13             0.15          0.743        1.00473          1.4085
# 14             0.15          0.720        0.94120          1.0860
# 15             0.15          0.797        0.57664          1.6320
# 16             0.15          0.783        1.19126          2.6670
# 17             0.15          0.765        2.76760          4.8840
# 18             0.15          0.717        1.28212          1.4460
# 19             0.15          0.768        0.56580          1.0350
# 20             0.15          0.783        0.97418          2.1810
# 21             0.15          0.743        1.69274          2.3730
# 22             0.15          0.774        1.32240          2.6100
# 23             0.15          0.745        1.47210          2.1030
# 24             0.15          0.757        0.48732          0.7860
# 25             0.15          0.756        0.54238          0.8655
# 26             0.15          0.722        1.18016          1.3830
# 27             0.15          0.777        0.81176          1.6680
# 28             0.15          0.730        0.40560          0.5070
# 29             0.15          0.799        1.42494          4.1910
# 30             0.15          0.714        2.66560          2.9400
# 31             0.15          0.741        0.68452          0.9420
# 32             0.15          0.722        1.18016          1.3830
# 33             0.15          0.799        1.59222          4.6830
# 34             0.15          0.766        0.89712          1.6020
# 35             0.15          0.712        3.24438          3.5265
# 36             0.15          0.702        0.43364          0.4395
# 37             0.15          0.777        1.71988          3.5340
# 38             0.15          0.775        1.12200          2.2440
# 39             0.15          0.797        0.54802          1.5510
# 40             0.15          0.743        2.45672          3.4440
# 41             0.15          0.706        1.67904          1.7490
# 42             0.15          0.724        1.11888          1.3320
# 43             0.15          0.717        2.17854          2.4570
# 44             0.15          0.775        0.80400          1.6080
# 45             0.15          0.717        1.36458          1.5390
# 46             0.15          0.702        1.72864          1.7520
# 47             0.15          0.774        1.64464          3.2460
# 48             0.15          0.743        0.82390          1.1550
# 49             0.15          0.782        0.64600          1.4250
#
#     Product Cost
# 0        8.65200
# 1       16.98240
# 2        9.35693
# 3        2.65760
# 4        3.21930
# 5        2.05130
# 6        2.47640
# 7        2.83125
# 8        4.09968
# 9        5.65020
# 10       4.56300
# 11       3.58020
# 12       4.91490
# 13       6.97677
# 14       5.21280
# 15       8.67136
# 16      13.92174
# 17      24.90840
# 18       6.91188
# 19       5.29920
# 20      11.38482
# 21      11.75426
# 22      13.46760
# 23      10.44490
# 24       3.96668
# 25       4.36212
# 26       6.65684
# 27       8.64024
# 28       2.46740
# 29      22.32406
# 30      13.99440
# 31       4.65348
# 32       6.65684
# 33      24.94478
# 34       8.18088
# 35      16.73912
# 36       2.05686
# 37      18.30612
# 38      11.59400
# 39       8.24098
# 40      17.05928
# 41       8.23196
# 42       6.42912
# 43      11.74446
# 44       8.30800
# 45       7.35642
# 46       8.19936
# 47      16.74936
# 48       5.72110
# 49       7.42900
#
# [50 rows x 32 columns]

# %% [markdown]
# Також можна переглянути, чи є пропущені значення. Як бачимо, в цьому дадасеті їх немає.

# %%
missing_values = df.isnull().sum()
missing_values
# Out:
# Receipt Number         0
# Date                   0
# Year                   0
# Month                  0
# Time                   0
# Mobile Number          0
# Membership ID          0
# Loyalty Card Points    0
# Age                    0
# Gender                 0
# City                   0
# Country                0
# Category               0
# Sub_Category           0
# Items                  0
# Brand                  0
# Description            0
# Price                  0
# QTY                    0
# DISC                   0
# Amount                 0
# Net Bill Amount        0
# GST                    0
# Gross Bill Amount      0
# Payment Mode           0
# Bank Name              0
# % Profit Margin        0
# % Operating Cost       0
# % Product Cost         0
# Profit Margin          0
# Operating Cost         0
# Product Cost           0
# dtype: int64

# %% [markdown]
# 1. Можна подивитися в яких містах які групи товарів найбільш прибуткові.

# %%
pivot_payment_method_margin = df.pivot_table(index='City', columns="Category", values ='Profit Margin')
pivot_payment_method_margin.style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
# #T_7c923fae_555c_11ee_ad69_141333235e28row0_col0{
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row0_col1{
#             background-color:  #328dbf;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row0_col2{
#             background-color:  #b1c2de;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row0_col3{
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row0_col4{
#             background-color:  #e0deed;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row0_col5{
#             background-color:  #4c99c5;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row0_col6,#T_7c923fae_555c_11ee_ad69_141333235e28row1_col8{
#             background-color:  #b7c5df;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row0_col7{
#             background-color:  #04649e;
#             color:  #f1f1f1;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row0_col8{
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row0_col9{
#             background-color:  #f4edf6;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row0_col10{
#             background-color:  #046096;
#             color:  #f1f1f1;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row0_col11,#T_7c923fae_555c_11ee_ad69_141333235e28row1_col11,#T_7c923fae_555c_11ee_ad69_141333235e28row2_col15,#T_7c923fae_555c_11ee_ad69_141333235e28row3_col15,#T_7c923fae_555c_11ee_ad69_141333235e28row4_col15{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row0_col12,#T_7c923fae_555c_11ee_ad69_141333235e28row3_col0,#T_7c923fae_555c_11ee_ad69_141333235e28row4_col6{
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row0_col13{
#             background-color:  #84b0d3;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row0_col14,#T_7c923fae_555c_11ee_ad69_141333235e28row1_col14,#T_7c923fae_555c_11ee_ad69_141333235e28row2_col14,#T_7c923fae_555c_11ee_ad69_141333235e28row3_col14,#T_7c923fae_555c_11ee_ad69_141333235e28row4_col14{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row0_col15{
#             background-color:  #034267;
#             color:  #f1f1f1;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row1_col0{
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row1_col1{
#             background-color:  #358fc0;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row1_col2{
#             background-color:  #a8bedc;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row1_col3{
#             background-color:  #c9cee4;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row1_col4,#T_7c923fae_555c_11ee_ad69_141333235e28row2_col12{
#             background-color:  #dfddec;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row1_col5{
#             background-color:  #4897c4;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row1_col6,#T_7c923fae_555c_11ee_ad69_141333235e28row3_col2{
#             background-color:  #b0c2de;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row1_col7{
#             background-color:  #197db7;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row1_col9{
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row1_col10{
#             background-color:  #045382;
#             color:  #f1f1f1;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row1_col12,#T_7c923fae_555c_11ee_ad69_141333235e28row4_col3{
#             background-color:  #c8cde4;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row1_col13{
#             background-color:  #6fa7ce;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row1_col15{
#             background-color:  #023d60;
#             color:  #f1f1f1;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row2_col0,#T_7c923fae_555c_11ee_ad69_141333235e28row3_col12{
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row2_col1,#T_7c923fae_555c_11ee_ad69_141333235e28row4_col5{
#             background-color:  #4697c4;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row2_col2{
#             background-color:  #b5c4df;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row2_col3{
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row2_col4,#T_7c923fae_555c_11ee_ad69_141333235e28row4_col4{
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row2_col5{
#             background-color:  #549cc7;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row2_col6,#T_7c923fae_555c_11ee_ad69_141333235e28row4_col12{
#             background-color:  #ced0e6;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row2_col7{
#             background-color:  #0771b1;
#             color:  #f1f1f1;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row2_col8{
#             background-color:  #c5cce3;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row2_col9{
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row2_col10{
#             background-color:  #0566a0;
#             color:  #f1f1f1;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row2_col11{
#             background-color:  #045a8d;
#             color:  #f1f1f1;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row2_col13{
#             background-color:  #8bb2d4;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row3_col1{
#             background-color:  #3f93c2;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row3_col3{
#             background-color:  #c2cbe2;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row3_col4{
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row3_col5{
#             background-color:  #63a2cb;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row3_col6{
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row3_col7{
#             background-color:  #157ab5;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row3_col8{
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row3_col9,#T_7c923fae_555c_11ee_ad69_141333235e28row4_col9{
#             background-color:  #f5eef6;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row3_col10{
#             background-color:  #04588a;
#             color:  #f1f1f1;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row3_col11{
#             background-color:  #03476f;
#             color:  #f1f1f1;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row3_col13{
#             background-color:  #80aed2;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row4_col0{
#             background-color:  #d3d4e7;
#             color:  #000000;
#         }#T_7c923fae_555c_11ee_ad69_141333235e28row4_col1{
#             background-color:  #2685bb;
#             co

# %% [markdown]
# Зі зведеною таблиці бачимо однакові тренди в усіх містах - група товарів Wines, Beers & Spirits є найбільш прибутковою. Дві інші категорії, які генерують найбільше прибутків - Mother & Baby та Meat & Seafood.

# %% [markdown]
# 2. Також можемо подивитися які саме товари є найбільш прибутковими. Це в переважній більшості вино і шампанське, але також є дитяче зарчування на 9 позиції. Можливо, є сенс продавати більше таких товарів.

# %%
average_profit_margin = df.groupby('Items')['Profit Margin'].mean().sort_values(ascending=False).head(10)
plt.figure(figsize=(12, 7))
average_profit_margin.plot(kind='barh', color='purple')
plt.title('10 товарів з найвищою прибутковістю')
plt.xlabel('Середня прибутковість')
plt.ylabel('Назва товару')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %% [markdown]
# 3. Можна також подивитися якою в процентному відношенні є прибутковість кожної групи товарів і побачити які категорії товарів в процентному відношенні генерують найбільші прибутки. Як ми бачимо нижче, категорія Frozen приносить трохи більше 15% всіх прибутків, також найбільш прибутковими категоріями з цієї точки зору є категорія Beauty та Bekary and Breakfast.

# %%
profit_by_category = df.groupby('Category')['Profit Margin'].sum()

plt.figure(figsize=(10, 7))
plt.pie(profit_by_category, labels=profit_by_category.index, autopct='%1.1f%%', startangle=140, wedgeprops=dict(width=0.3))
plt.title('Розподіл прибутковості по категоріях товарів')
plt.show()

# %% [markdown]
# 4. Ми також можемо подивитися і проаналізувати, в які дні тижня більше покупців. На графіку не можна прослідкувати однакової тенденції по всіх містах. Тобто, планування маркетингових заходів краще робити, спираючись на дані конкретного міста.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df['Day_of_Week'] = df['Date'].dt.day_name()

grouped_data = df.groupby(['City', 'Day_of_Week']).size().unstack().reindex(columns=order_of_days)

ax = grouped_data.transpose().plot(kind='bar', figsize=(14, 8), width=0.8)
ax.set_title('Попит в містах в залежності від дня тижня.')
ax.set_xlabel('Day of the Week')
ax.set_ylabel('Number of Purchases')
ax.set_xticklabels(order_of_days, rotation=45)
ax.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# 5. На наступному графіку видно динаміку щомісячного прибутку. Можна побачити, що прибутки стабільно зростають. Пік прибутковості припадає на новорічний період, після чого кожного року йде спад. Можливо, є сенс простимулювати попит після новорічних свят.

# %%
monthly_sales = df.groupby(['Year', 'Month'])['Profit Margin'].sum().reset_index()
plt.figure(figsize=(15, 7))
plt.plot(monthly_sales['Year'].astype(str) + '-' + monthly_sales['Month'].astype(int).astype(str), monthly_sales['Profit Margin'], marker='o')
plt.xticks(rotation=45)
plt.title('Динаміка щомісячного прибутку')
plt.xlabel('Рік - місяць')
plt.ylabel('Прибутковість')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# 6. На графіку нижче можна побачити покупці якого віку приносять найбільше прибутку - найбільш активним покупцям близько 20 років. Найменше прибутку приносять люди близько 60 років та старше. Можна сфокусуватися на молодій аудиторії, а можна подумати як простимулювати більш старших покупців робити покупки (наприклад, за допомогою доставки товарів).

# %%
import matplotlib.pyplot as plt

# Create a histogram using profit margin as weights
plt.figure(figsize=(8, 6))
plt.hist(df['Age'], bins=20, weights=df['Profit Margin'], color='green', edgecolor='black')

# Set the title and labels
plt.title('Розподіл прибутку за віком')
plt.xlabel('Вік')
plt.ylabel('Сума прибутку')
plt.tight_layout()
plt.show()

# %% [markdown]
# 7.Також можна подивитися на розподіл за статтю. Як ми бачимо, чоловіків в 4 рази менше, ніж жінок. Це дає нам уявлення про те, хто є найголовнішою цільовою аудиторією і як краще рекламувати товари.

# %%
plt.figure(figsize=(8, 6))
df['Gender'].value_counts().plot(kind='bar', color=['lightpink', 'lightskyblue'])
plt.title('Розподіл покупців за ознакою статі')
plt.xlabel('Стать')
plt.ylabel('Кількість транзакцій')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# 8. Ми також можемо переглянути який розподіл чоловіків/жінок в покупців віку 15-23. Як ми бачимо, кількість жінок цього віку переважає в 5 разів. Це ще раз підтверджує, що має сенс для цієї вікової групи робити маркетингові кампанії саме для жінок.

# %%
age_filtered_df = df[(df['Age'] >= 15) & (df['Age'] <= 23)]
gender_counts = age_filtered_df['Gender'].value_counts()
print(gender_counts)
# Out:
# Female    10847
# Male       2050
# Name: Gender, dtype: int64

# %% [markdown]
# 9. Також можна подивитися, чи впливає форма оплати на користування покупцями картами лояльності. Як ми бачимо з графіку нижче, балів на карті лояльності трохи більше у покупців, які користуються банківською картою, але різниця незначна.

# %%
plt.figure(figsize=(40, 30))

sns.boxplot(x="Payment Mode", y="Loyalty Card Points", data=df)

plt.title("Кількість балів на картках лояльності в залежності форми оплати", fontsize=30)

plt.xlabel("Форма оплати", fontsize=25)
plt.ylabel("Бали на карті лояльності", fontsize=25)

plt.xticks(fontsize=30)

plt.show()

# %% [markdown]
# 10. Також можна порівняти чи є якась різниця між чоловіками та жінками у використанні картки лояльності. Як ми бачимо з графіку, різниці практично немає, у чоловіків навіть трішки більше балів.

# %%
plt.figure(figsize=(8, 6))

sns.boxplot(data=df, x='Gender', y='Loyalty Card Points', palette=['lightskyblue', 'lightpink'])

plt.title('Бали на картці лояльності в залежності від статі')
plt.xlabel('Стать')
plt.ylabel('Бали на картці лояльності')

plt.tight_layout()
plt.show()
